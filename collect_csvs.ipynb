# %%
from collect import Collector

# %%
files = ["/home/muhammad/SGLI/ocsmart_processed/test.csv", "/home/muhammad/SGLI/ocsmart_processed/train.csv"]
columns = ["MATCHUP_VALID", 'lat', 'lon', 'Rrs_380', 'Rrs_412', 'Rrs_443', 'Rrs_490', 'Rrs_530', 'Rrs_565', 'Rrs_672', 'AOD_380', 'AOD_412', 'AOD_443', 'AOD_490', 'AOD_530', 'AOD_565', 'AOD_672', 'adg_380', 'adg_412', 'adg_443', 'adg_490', 'adg_530', 'adg_565', 'adg_672', 'ap_380', 'ap_412', 'ap_443', 'ap_490', 'ap_530', 'ap_565', 'ap_672', 'aph_380', 'aph_412', 'aph_443', 'aph_490', 'aph_530', 'aph_565', 'aph_672', 'bbp_380', 'bbp_412', 'bbp_443', 'bbp_490', 'bbp_530', 'bbp_565', 'bbp_672', 'bp_380', 'bp_412', 'bp_443', 'bp_490', 'bp_530', 'bp_565', 'bp_672', 'Chla_oci', 'Chla_yoc', 'TSM_yoc', 'l2_flags', 'in_situ_lat', 'in_situ_lon', 'Global_ID', 'Date', 'l1b_gportal_id']

important = ['MATCHUP_VALID', 'lat', 'lon', 'l2_flags', 'in_situ_lat', 'in_situ_lon', 'Global_ID', 'Date','Rrs_412', 'Rrs_443', 'Rrs_490', 'Rrs_530', 'Rrs_565', 'Rrs_672', "Chla_oci", "Chla_yoc"]
outfile = "/home/muhammad/SGLI/ocsmart_processed/matchup.csv"

# %%
columns = ['MATCHUP_VALID','lat', 'lon', 'Kd_490', 'Rrs_380', 'Rrs_412', 'Rrs_443', 'Rrs_490', 'Rrs_529', 'Rrs_566', 'Rrs_672', 'a_380_qaa', 'a_412_qaa', 'a_443_qaa', 'a_490_qaa', 'a_566_qaa', 'a_672_qaa', 'adg_380_qaa', 'adg_412_qaa', 'adg_443_qaa', 'adg_490_qaa', 'adg_529_qaa', 'adg_566_qaa', 'adg_672_qaa', 'angstrom', 'aot_867', 'aph_380_qaa', 'aph_412_qaa', 'aph_443_qaa', 'aph_490_qaa', 'aph_529_qaa', 'aph_566_qaa', 'aph_672_qaa', 'chlor_a', 'l2_flags', 'in_situ_lat', 'in_situ_lon', 'Global_ID', 'Date', 'l1b_gportal_id']
files = ["/home/muhammad/SGLI/seadas_processed/test.csv", "/home/muhammad/SGLI/seadas_processed/train.csv"]
important = ['MATCHUP_VALID','lat', 'lon', 'l2_flags', 'in_situ_lat', 'in_situ_lon', 'Global_ID', 'Date','Rrs_412', 'Rrs_443', 'Rrs_490', 'Rrs_529', 'Rrs_566', 'Rrs_672', 'chlor_a']
outfile = "/home/muhammad/SGLI/seadas_processed/matchup.csv"

# %%
files = ["/home/muhammad/SGLI/l2_std/test.csv", "/home/muhammad/SGLI/l2_std/train.csv"]
columns = ["Global_ID", "lat", "lon", "Date", "l1b_gportal_id", "l2_rrs_gportal_id", "l2_prod_gportal_id", "Rrs_380", "Rrs_412", "Rrs_443", "Rrs_490", "Rrs_530", "Rrs_565", "Rrs_670", "Rrs_765", "Rrs_flags", "prod_flags", "Chla", "TSM", "ag_443", "MATCHUP_VALID"]
important = ["MATCHUP_VALID", "Global_ID", "lat", "lon", "Date", "Rrs_412", "Rrs_443", "Rrs_490", "Rrs_530", "Rrs_565", "Rrs_670", "Rrs_flags", "prod_flags", "Chla"]
outfile = "/home/muhammad/SGLI/l2_std/matchup.csv"

# %%
c = Collector(files, columns, important, outfile)
df = c.start()
# Out:
# /home/muhammad/process_sgli/collect.py:27: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df =pd.concat([df, f_df], axis=0)

# %%
df
# Out:
#     MATCHUP_VALID        lat         lon l2_flags  in_situ_lat  in_situ_lon  \
# 0           False  46.500343    6.661405      256    46.500150     6.660780
# 1            True  30.730070  114.283890        0    30.730801   114.283493
# 2            True  30.546324  114.385925        0    30.546469   114.385590
# 3            True  46.500603    6.661223        0    46.500150     6.660780
# 4            True  41.703777  -83.256560        0    41.703600   -83.255400
# ..            ...        ...         ...      ...          ...          ...
# 342          True  46.499820    6.660415        0    46.500150     6.660780
# 343          True -33.076584  -57.437424        0   -33.076484   -57.436548
# 344         False  48.343220   -4.681359      256    48.344234    -4.680833
# 345          True  30.544693  114.426820        0    30.544135   114.427295
# 346         False  42.810577  -70.827620        0    42.809510   -70.827260
#
# ...
